# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import mean_squared_error

# Example sigmoid function
def sigmoid(z):
    return 1 / (1 + np.exp(-z))

# Train model1 (1D logistic regression)
model1 = LogisticRegression()
model1.fit(X1, y1)

# Range for sigmoid curve
x_range = np.linspace(0, 100, 300).reshape(-1, 1)
linear_pred = model1.coef_[0][0] * x_range + model1.intercept_[0]
probs = sigmoid(linear_pred)

# Predictions on training data
y_pred_probs = model1.predict_proba(X1)[:, 1]
y_pred_class = model1.predict(X1)

# Mean Error (Mean Squared Error here)
mean_error = mean_squared_error(y1, y_pred_probs)

# -------------------
# Plot 1D Sigmoid Curve
# -------------------
plt.figure(figsize=(8, 6))
plt.scatter(X1, y1, c=y1, cmap="bwr", alpha=0.7)
plt.plot(x_range, probs, color="black", linewidth=2, label="Sigmoid Curve")
plt.axhline(0.5, color="gray", linestyle="--")
plt.title("1D Logistic Regression (Sigmoid Curve)")
plt.xlabel("Feature Value")
plt.ylabel("Probability of Class 1")
plt.legend()
plt.show()

# Print mean error and outputs
print("Mean Squared Error:", mean_error*100)
# Out:
# Mean Squared Error: 0.36600804344623733
